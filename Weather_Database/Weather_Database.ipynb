# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | noumea
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 1 | laguna
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | sitka
# Processing Record 7 of Set 1 | kavieng
# Processing Record 8 of Set 1 | san patricio
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | kalisz
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | elizabeth city
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | sao joao da barra
# Processing Record 15 of Set 1 | metro
# Processing Record 16 of Set 1 | asau
# Processing Record 17 of Set 1 | gorno-altaysk
# Processing Record 18 of Set 1 | lokosovo
# Processing Record 19 of Set 1 | marfino
# Processing Record 20 of Set 1 | qandala
# Processing Record 21 of Set 1 | afonso bezerra
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | hinton
# Processing Record 26 of Set 1 | ulaanbaatar
# Processing Record 27 of Set 1 | ilulissat
# Processing Record 28 of Set 1 | abu dhabi
# Processing Record 29 of Set 1 | hovd
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | casper
# Processing Record 34 of Set 1 | adrar
# Processing Record 35 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | guarapari
# Processing Record 38 of Set 1 | codrington
# Processing Record 39 of Set 1 | jimo
# Processing Record 40 of Set 1 | plettenberg bay
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | cesky dub
# Processing Record 43 of Set 1 | saint-augustin
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | port-gentil
# Processing Record 46 of Set 1 | mount gambier
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | khani
# Processing Record 50 of Set 1 | samarai
# Processing Record 1 of Set 2 | dingle
# Processing Record 2 of Set 2 | husavik
# Processing Record 3 of Set 2 | carutapera
# Processing Record 4 of Set 2 | hasaki
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | kiunga
# Processing Record 10 of Set 2 | saint george
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | grindavik
# Processing Record 16 of Set 2 | mount isa
# Processing Record 17 of Set 2 | gandzak
# Processing Record 18 of Set 2 | acapulco
# Processing Record 19 of Set 2 | vicuna
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | oranjestad
# Processing Record 22 of Set 2 | thunder bay
# Processing Record 23 of Set 2 | pontal do parana
# Processing Record 24 of Set 2 | severo-kurilsk
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | weiser
# Processing Record 27 of Set 2 | bondo
# Processing Record 28 of Set 2 | jahrom
# City not found. Skipping...
# Processing Record 29 of Set 2 | makakilo city
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | alofi
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | trincomalee
# Processing Record 35 of Set 2 | bin qirdan
# Processing Record 36 of Set 2 | hamilton
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | beringovskiy
# Processing Record 39 of Set 2 | onalaska
# Processing Record 40 of Set 2 | braco do norte
# Processing Record 41 of Set 2 | marawi
# Processing Record 42 of Set 2 | souillac
# Processing Record 43 of Set 2 | hambantota
# Processing Record 44 of Set 2 | vila
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | camacha
# Processing Record 47 of Set 2 | canmore
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 3 | natal
# Processing Record 2 of Set 3 | emba
# Processing Record 3 of Set 3 | kodiak
# Processing Record 4 of Set 3 | coahuayana
# Processing Record 5 of Set 3 | port lincoln
# Processing Record 6 of Set 3 | castro
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | tighina
# Processing Record 10 of Set 3 | lorengau
# Processing Record 11 of Set 3 | brae
# Processing Record 12 of Set 3 | wattegama
# Processing Record 13 of Set 3 | acarau
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | kamaishi
# Processing Record 18 of Set 3 | cape town
# Processing Record 19 of Set 3 | aklavik
# Processing Record 20 of Set 3 | kawalu
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 3 | poum
# Processing Record 25 of Set 3 | tuatapere
# Processing Record 26 of Set 3 | deputatskiy
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | nome
# Processing Record 29 of Set 3 | touho
# Processing Record 30 of Set 3 | katsuura
# Processing Record 31 of Set 3 | merke
# Processing Record 32 of Set 3 | narsaq
# Processing Record 33 of Set 3 | saint-philippe
# Processing Record 34 of Set 3 | bognor regis
# Processing Record 35 of Set 3 | san antonio
# Processing Record 36 of Set 3 | shingu
# Processing Record 37 of Set 3 | clyde river
# Processing Record 38 of Set 3 | rawlins
# Processing Record 39 of Set 3 | safaga
# Processing Record 40 of Set 3 | botwood
# Processing Record 41 of Set 3 | auki
# Processing Record 42 of Set 3 | mitu
# Processing Record 43 of Set 3 | mahibadhoo
# Processing Record 44 of Set 3 | ojo caliente
# Processing Record 45 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 46 of Set 3 | nenjiang
# Processing Record 47 of Set 3 | chokurdakh
# Processing Record 48 of Set 3 | tessalit
# Processing Record 49 of Set 3 | bengkulu
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | batagay-alyta
# Processing Record 2 of Set 4 | fairbanks
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 4 | yakeshi
# Processing Record 6 of Set 4 | kalaleh
# Processing Record 7 of Set 4 | saldanha
# Processing Record 8 of Set 4 | phan thiet
# Processing Record 9 of Set 4 | san cristobal
# Processing Record 10 of Set 4 | tazovskiy
# Processing Record 11 of Set 4 | la ronge
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | arcos
# Processing Record 14 of Set 4 | glasgow
# Processing Record 15 of Set 4 | victoria
# Processing Record 16 of Set 4 | bamiantong
# Processing Record 17 of Set 4 | northam
# Processing Record 18 of Set 4 | arraial do cabo
# Processing Record 19 of Set 4 | tiksi
# Processing Record 20 of Set 4 | manthani
# Processing Record 21 of Set 4 | ukiah
# Processing Record 22 of Set 4 | emerald
# Processing Record 23 of Set 4 | kahului
# Processing Record 24 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 4 | sao filipe
# Processing Record 26 of Set 4 | lasa
# Processing Record 27 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 4 | oussouye
# Processing Record 29 of Set 4 | fort nelson
# Processing Record 30 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 4 | oulu
# Processing Record 32 of Set 4 | avarua
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | darnah
# Processing Record 35 of Set 4 | werder
# Processing Record 36 of Set 4 | lavrentiya
# Processing Record 37 of Set 4 | launceston
# Processing Record 38 of Set 4 | verkhoyansk
# Processing Record 39 of Set 4 | airai
# Processing Record 40 of Set 4 | east london
# Processing Record 41 of Set 4 | ware
# Processing Record 42 of Set 4 | namatanai
# Processing Record 43 of Set 4 | banda aceh
# Processing Record 44 of Set 4 | paamiut
# Processing Record 45 of Set 4 | ibotirama
# Processing Record 46 of Set 4 | iqaluit
# Processing Record 47 of Set 4 | jizan
# Processing Record 48 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 4 | cabinda
# Processing Record 50 of Set 4 | guerrero negro
# Processing Record 1 of Set 5 | sesheke
# Processing Record 2 of Set 5 | port hardy
# Processing Record 3 of Set 5 | honiara
# Processing Record 4 of Set 5 | lompoc
# Processing Record 5 of Set 5 | port blair
# Processing Record 6 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 5 | abiy adi
# City not found. Skipping...
# Processing Record 8 of Set 5 | oum hadjer
# Processing Record 9 of Set 5 | lucapa
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 12 of Set 5 | atuona
# Processing Record 13 of Set 5 | campoverde
# Processing Record 14 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 5 | kismayo
# Processing Record 16 of Set 5 | senmonorom
# City not found. Skipping...
# Processing Record 17 of Set 5 | zahir pir
# Processing Record 18 of Set 5 | beyneu
# Processing Record 19 of Set 5 | araouane
# Processing Record 20 of Set 5 | meulaboh
# Processing Record 21 of Set 5 | amga
# Processing Record 22 of Set 5 | odweyne
# Processing Record 23 of Set 5 | dikson
# Processing Record 24 of Set 5 | kyren
# Processing Record 25 of Set 5 | norton
# Processing Record 26 of Set 5 | forestville
# Processing Record 27 of Set 5 | ahipara
# Processing Record 28 of Set 5 | goderich
# Processing Record 29 of Set 5 | chase
# Processing Record 30 of Set 5 | mago
# Processing Record 31 of Set 5 | lebu
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | nanortalik
# Processing Record 34 of Set 5 | cabo san lucas
# Processing Record 35 of Set 5 | saint-joseph
# Processing Record 36 of Set 5 | egvekinot
# Processing Record 37 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 5 | san rafael del sur
# Processing Record 39 of Set 5 | barcelona
# Processing Record 40 of Set 5 | gikongoro
# Processing Record 41 of Set 5 | bakaly
# Processing Record 42 of Set 5 | candido de abreu
# Processing Record 43 of Set 5 | portland
# Processing Record 44 of Set 5 | riaba
# City not found. Skipping...
# Processing Record 45 of Set 5 | heihe
# Processing Record 46 of Set 5 | san quintin
# Processing Record 47 of Set 5 | cloquet
# Processing Record 48 of Set 5 | cascais
# Processing Record 49 of Set 5 | takaka
# Processing Record 50 of Set 5 | kavaratti
# Processing Record 1 of Set 6 | sinnamary
# Processing Record 2 of Set 6 | turinsk
# Processing Record 3 of Set 6 | avera
# Processing Record 4 of Set 6 | dinguiraye
# Processing Record 5 of Set 6 | tabriz
# Processing Record 6 of Set 6 | hervey bay
# Processing Record 7 of Set 6 | afgoye
# City not found. Skipping...
# Processing Record 8 of Set 6 | rafsanjan
# Processing Record 9 of Set 6 | kysyl-syr
# Processing Record 10 of Set 6 | westport
# Processing Record 11 of Set 6 | salalah
# Processing Record 12 of Set 6 | ancud
# Processing Record 13 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 6 | russell
# Processing Record 15 of Set 6 | manono
# Processing Record 16 of Set 6 | vao
# Processing Record 17 of Set 6 | porto santo
# Processing Record 18 of Set 6 | luocheng
# Processing Record 19 of Set 6 | iisalmi
# Processing Record 20 of Set 6 | nikolayevsk-na-amure
# Processing Record 21 of Set 6 | esmeraldas
# Processing Record 22 of Set 6 | jinhua
# Processing Record 23 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 6 | tottori
# Processing Record 25 of Set 6 | tual
# Processing Record 26 of Set 6 | faqirwali
# Processing Record 27 of Set 6 | vardo
# Processing Record 28 of Set 6 | kruisfontein
# Processing Record 29 of Set 6 | darhan
# Processing Record 30 of Set 6 | henties bay
# Processing Record 31 of Set 6 | roebourne
# Processing Record 32 of Set 6 | apatity
# Processing Record 33 of Set 6 | grenaa
# Processing Record 34 of Set 6 | talnakh
# Processing Record 35 of Set 6 | sepuka
# Processing Record 36 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 6 | klaksvik
# Processing Record 38 of Set 6 | mahebourg
# Processing Record 39 of Set 6 | kattivakkam
# Processing Record 40 of Set 6 | dunedin
# Processing Record 41 of Set 6 | himora
# City not found. Skipping...
# Processing Record 42 of Set 6 | tacoronte
# Processing Record 43 of Set 6 | torbay
# Processing Record 44 of Set 6 | sorland
# Processing Record 45 of Set 6 | mildura
# Processing Record 46 of Set 6 | anori
# Processing Record 47 of Set 6 | moron
# Processing Record 48 of Set 6 | moerai
# Processing Record 49 of Set 6 | saryg-sep
# Processing Record 50 of Set 6 | caravelas
# Processing Record 1 of Set 7 | najran
# Processing Record 2 of Set 7 | basco
# Processing Record 3 of Set 7 | palu
# Processing Record 4 of Set 7 | carnarvon
# Processing Record 5 of Set 7 | usa river
# Processing Record 6 of Set 7 | korla
# Processing Record 7 of Set 7 | xining
# Processing Record 8 of Set 7 | ponyri
# Processing Record 9 of Set 7 | kutum
# Processing Record 10 of Set 7 | altay
# Processing Record 11 of Set 7 | boone
# Processing Record 12 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 13 of Set 7 | saint-francois
# Processing Record 14 of Set 7 | lucea
# Processing Record 15 of Set 7 | bonavista
# Processing Record 16 of Set 7 | el balyana
# City not found. Skipping...
# Processing Record 17 of Set 7 | birao
# Processing Record 18 of Set 7 | vila velha
# Processing Record 19 of Set 7 | pangnirtung
# Processing Record 20 of Set 7 | dwarka
# Processing Record 21 of Set 7 | vestmannaeyjar
# Processing Record 22 of Set 7 | vila franca do campo
# Processing Record 23 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 7 | mayo
# Processing Record 25 of Set 7 | zhigansk
# Processing Record 26 of Set 7 | gumdag
# Processing Record 27 of Set 7 | bayonet point
# Processing Record 28 of Set 7 | shangrao
# Processing Record 29 of Set 7 | ribeira grande
# Processing Record 30 of Set 7 | magadan
# Processing Record 31 of Set 7 | key largo
# Processing Record 32 of Set 7 | shchigry
# Processing Record 33 of Set 7 | nizhniy tsasuchey
# Processing Record 34 of Set 7 | maua
# Processing Record 35 of Set 7 | srednekolymsk
# Processing Record 36 of Set 7 | jijiga
# Processing Record 37 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 7 | sakakah
# Processing Record 39 of Set 7 | bentiu
# Processing Record 40 of Set 7 | monrovia
# Processing Record 41 of Set 7 | gavle
# Processing Record 42 of Set 7 | bereda
# Processing Record 43 of Set 7 | ostrovnoy
# Processing Record 44 of Set 7 | oranjemund
# Processing Record 45 of Set 7 | bandarbeyla
# Processing Record 46 of Set 7 | keroka
# Processing Record 47 of Set 7 | manadhoo
# Processing Record 48 of Set 7 | santa maria
# Processing Record 49 of Set 7 | isangel
# Processing Record 50 of Set 7 | hohoe
# Processing Record 1 of Set 8 | ola
# Processing Record 2 of Set 8 | gashua
# Processing Record 3 of Set 8 | olga
# Processing Record 4 of Set 8 | hualmay
# Processing Record 5 of Set 8 | montepuez
# Processing Record 6 of Set 8 | vostok
# Processing Record 7 of Set 8 | esil
# Processing Record 8 of Set 8 | santona
# Processing Record 9 of Set 8 | lisakovsk
# Processing Record 10 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 8 | hare bay
# Processing Record 12 of Set 8 | beirut
# Processing Record 13 of Set 8 | malmo
# Processing Record 14 of Set 8 | gavrilov-yam
# Processing Record 15 of Set 8 | yumen
# Processing Record 16 of Set 8 | baglung
# Processing Record 17 of Set 8 | padang
# Processing Record 18 of Set 8 | danjiangkou
# Processing Record 19 of Set 8 | martinez
# Processing Record 20 of Set 8 | arica
# Processing Record 21 of Set 8 | kaitangata
# Processing Record 22 of Set 8 | olinda
# Processing Record 23 of Set 8 | tromso
# Processing Record 24 of Set 8 | inongo
# Processing Record 25 of Set 8 | haines junction
# Processing Record 26 of Set 8 | greymouth
# Processing Record 27 of Set 8 | rudbar
# Processing Record 28 of Set 8 | sarlat-la-caneda
# Processing Record 29 of Set 8 | tura
# Processing Record 30 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 8 | quang ngai
# Processing Record 32 of Set 8 | santa luzia
# Processing Record 33 of Set 8 | la seyne-sur-mer
# Processing Record 34 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 8 | mahon
# Processing Record 36 of Set 8 | byron bay
# Processing Record 37 of Set 8 | pisco
# Processing Record 38 of Set 8 | buenos aires
# Processing Record 39 of Set 8 | flinders
# Processing Record 40 of Set 8 | la cruz
# Processing Record 41 of Set 8 | faanui
# Processing Record 42 of Set 8 | chapais
# Processing Record 43 of Set 8 | barcelos
# Processing Record 44 of Set 8 | leningradskiy
# Processing Record 45 of Set 8 | zhezkazgan
# Processing Record 46 of Set 8 | pervomayskoye
# Processing Record 47 of Set 8 | shitanjing
# Processing Record 48 of Set 8 | bairiki
# Processing Record 49 of Set 8 | cockburn town
# Processing Record 50 of Set 8 | nouadhibou
# Processing Record 1 of Set 9 | kieta
# Processing Record 2 of Set 9 | shimoda
# Processing Record 3 of Set 9 | pilar
# Processing Record 4 of Set 9 | raga
# Processing Record 5 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 6 of Set 9 | sapa
# Processing Record 7 of Set 9 | pontes e lacerda
# Processing Record 8 of Set 9 | ciudad bolivar
# Processing Record 9 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 9 | clonakilty
# Processing Record 11 of Set 9 | hit
# Processing Record 12 of Set 9 | velingara
# Processing Record 13 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 9 | ankazoabo
# Processing Record 15 of Set 9 | worland
# Processing Record 16 of Set 9 | lagoa
# Processing Record 17 of Set 9 | yulara
# Processing Record 18 of Set 9 | dakoro
# Processing Record 19 of Set 9 | itaituba
# Processing Record 20 of Set 9 | pochutla
# Processing Record 21 of Set 9 | galesong
# Processing Record 22 of Set 9 | seydi
# Processing Record 23 of Set 9 | north platte
# Processing Record 24 of Set 9 | paraiso
# Processing Record 25 of Set 9 | pierre
# Processing Record 26 of Set 9 | fastovetskaya
# Processing Record 27 of Set 9 | mattru
# Processing Record 28 of Set 9 | lerwick
# Processing Record 29 of Set 9 | roald
# Processing Record 30 of Set 9 | toila
# Processing Record 31 of Set 9 | ulagan
# Processing Record 32 of Set 9 | rawson
# Processing Record 33 of Set 9 | kirkkonummi
# Processing Record 34 of Set 9 | ascension
# Processing Record 35 of Set 9 | naze
# Processing Record 36 of Set 9 | constitucion
# Processing Record 37 of Set 9 | seminole
# Processing Record 38 of Set 9 | pahalgam
# Processing Record 39 of Set 9 | aykhal
# Processing Record 40 of Set 9 | batticaloa
# Processing Record 41 of Set 9 | havelock
# Processing Record 42 of Set 9 | cabedelo
# Processing Record 43 of Set 9 | yar-sale
# Processing Record 44 of Set 9 | kerema
# Processing Record 45 of Set 9 | visnes
# Processing Record 46 of Set 9 | severnoye
# Processing Record 47 of Set 9 | cayenne
# Processing Record 48 of Set 9 | nhulunbuy
# Processing Record 49 of Set 9 | verkhnyaya inta
# Processing Record 50 of Set 9 | cururupu
# Processing Record 1 of Set 10 | cherskiy
# Processing Record 2 of Set 10 | cabra
# Processing Record 3 of Set 10 | gizo
# Processing Record 4 of Set 10 | riohacha
# Processing Record 5 of Set 10 | luanda
# Processing Record 6 of Set 10 | gambela
# Processing Record 7 of Set 10 | mana
# Processing Record 8 of Set 10 | kununurra
# Processing Record 9 of Set 10 | lunsar
# Processing Record 10 of Set 10 | naron
# Processing Record 11 of Set 10 | pevek
# Processing Record 12 of Set 10 | baoro
# Processing Record 13 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 14 of Set 10 | fairview
# Processing Record 15 of Set 10 | basoko
# Processing Record 16 of Set 10 | marsh harbour
# Processing Record 17 of Set 10 | muros
# Processing Record 18 of Set 10 | la rioja
# Processing Record 19 of Set 10 | cape coast
# Processing Record 20 of Set 10 | saint-pierre
# Processing Record 21 of Set 10 | bilibino
# Processing Record 22 of Set 10 | hofn
# Processing Record 23 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 10 | coihaique
# Processing Record 25 of Set 10 | balkanabat
# Processing Record 26 of Set 10 | lyuban
# Processing Record 27 of Set 10 | navahrudak
# Processing Record 28 of Set 10 | shubarkuduk
# Processing Record 29 of Set 10 | pocone
# Processing Record 30 of Set 10 | waterford
# Processing Record 31 of Set 10 | bekhtery
# Processing Record 32 of Set 10 | yangambi
# Processing Record 33 of Set 10 | krasnoselkup
# Processing Record 34 of Set 10 | naryan-mar
# Processing Record 35 of Set 10 | esperance
# Processing Record 36 of Set 10 | falkenberg
# Processing Record 37 of Set 10 | waimana
# Processing Record 38 of Set 10 | la union
# Processing Record 39 of Set 10 | aksarka
# Processing Record 40 of Set 10 | maloy
# Processing Record 41 of Set 10 | boysun
# Processing Record 42 of Set 10 | marystown
# Processing Record 43 of Set 10 | sarakhs
# Processing Record 44 of Set 10 | toamasina
# Processing Record 45 of Set 10 | pozo colorado
# Processing Record 46 of Set 10 | presidencia roque saenz pena
# Processing Record 47 of Set 10 | ust-kulom
# Processing Record 48 of Set 10 | bathsheba
# Processing Record 49 of Set 10 | brigantine
# Processing Record 50 of Set 10 | jaggayyapeta
# Processing Record 1 of Set 11 | arman
# Processing Record 2 of Set 11 | seoul
# Processing Record 3 of Set 11 | formosa
# Processing Record 4 of Set 11 | cap malheureux
# Processing Record 5 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 11 | inuvik
# Processing Record 7 of Set 11 | tumen
# Processing Record 8 of Set 11 | majene
# Processing Record 9 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 11 | moratuwa
# Processing Record 11 of Set 11 | deqing
# Processing Record 12 of Set 11 | makaha
# Processing Record 13 of Set 11 | sovetskoye
# Processing Record 14 of Set 11 | vanimo
# Processing Record 15 of Set 11 | atagay
# Processing Record 16 of Set 11 | aguimes
# Processing Record 17 of Set 11 | isla vista
# Processing Record 18 of Set 11 | muroto
# Processing Record 19 of Set 11 | half moon bay
# Processing Record 20 of Set 11 | broome
# Processing Record 21 of Set 11 | balkhash
# Processing Record 22 of Set 11 | geraldton
# Processing Record 23 of Set 11 | sangar
# Processing Record 24 of Set 11 | semey
# Processing Record 25 of Set 11 | yatou
# Processing Record 26 of Set 11 | san juan
# Processing Record 27 of Set 11 | inhambane
# Processing Record 28 of Set 11 | richards bay
# Processing Record 29 of Set 11 | nishihara
# Processing Record 30 of Set 11 | kaka
# Processing Record 31 of Set 11 | sol-iletsk
# Processing Record 32 of Set 11 | san severo
# Processing Record 33 of Set 11 | meadow lake
# Processing Record 34 of Set 11 | huarmey
# Processing Record 35 of Set 11 | waipawa
# Processing Record 36 of Set 11 | roma
# Processing Record 37 of Set 11 | tank
# Processing Record 38 of Set 11 | riyadh
# Processing Record 39 of Set 11 | dandong
# Processing Record 40 of Set 11 | kovdor
# Processing Record 41 of Set 11 | zyryanka
# Processing Record 42 of Set 11 | port keats
# Processing Record 43 of Set 11 | kijang
# Processing Record 44 of Set 11 | simpang
# Processing Record 45 of Set 11 | vawkavysk
# Processing Record 46 of Set 11 | volosovo
# Processing Record 47 of Set 11 | pointe michel
# Processing Record 48 of Set 11 | onega
# Processing Record 49 of Set 11 | revelstoke
# Processing Record 50 of Set 11 | chilliwack
# Processing Record 1 of Set 12 | sarishabari
# Processing Record 2 of Set 12 | chunhuhub
# Processing Record 3 of Set 12 | yambio
# Processing Record 4 of Set 12 | yerbogachen
# Processing Record 5 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 12 | umm lajj
# Processing Record 7 of Set 12 | hami
# Processing Record 8 of Set 12 | ruidoso
# Processing Record 9 of Set 12 | sistranda
# Processing Record 10 of Set 12 | timmins
# Processing Record 11 of Set 12 | burnie
# Processing Record 12 of Set 12 | lunenburg
# Processing Record 13 of Set 12 | pacific grove
# Processing Record 14 of Set 12 | los llanos de aridane
# Processing Record 15 of Set 12 | juneau
# Processing Record 16 of Set 12 | santa isabel do rio negro
# Processing Record 17 of Set 12 | athabasca
# Processing Record 18 of Set 12 | itarema
# Processing Record 19 of Set 12 | port augusta
# Processing Record 20 of Set 12 | calvia
# Processing Record 21 of Set 12 | sobolevo
# Processing Record 22 of Set 12 | lakeside
# Processing Record 23 of Set 12 | tautira
# Processing Record 24 of Set 12 | ovalle
# Processing Record 25 of Set 12 | meiganga
# Processing Record 26 of Set 12 | marshall
# Processing Record 27 of Set 12 | khorixas
# Processing Record 28 of Set 12 | margate
# Processing Record 29 of Set 12 | hobyo
# Processing Record 30 of Set 12 | serenje
# Processing Record 31 of Set 12 | ixtapa
# Processing Record 32 of Set 12 | minsk
# Processing Record 33 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 12 | north bend
# Processing Record 35 of Set 12 | wajid
# Processing Record 36 of Set 12 | pahrump
# Processing Record 37 of Set 12 | khonsa
# Processing Record 38 of Set 12 | liverpool
# Processing Record 39 of Set 12 | maningrida
# Processing Record 40 of Set 12 | krasnyy kholm
# Processing Record 41 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 42 of Set 12 | skjervoy
# Processing Record 43 of Set 12 | itaqui
# Processing Record 44 of Set 12 | calama
# Processing Record 45 of Set 12 | ayorou
# Processing Record 46 of Set 12 | chifeng
# Processing Record 47 of Set 12 | cadillac
# Processing Record 48 of Set 12 | vysokogornyy
# Processing Record 49 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 50 of Set 12 | lima
# Processing Record 1 of Set 13 | waikuku
# Processing Record 2 of Set 13 | planeta rica
# Processing Record 3 of Set 13 | coracora
# Processing Record 4 of Set 13 | aksu
# Processing Record 5 of Set 13 | thanatpin
# Processing Record 6 of Set 13 | svetlyy
# Processing Record 7 of Set 13 | rocky mountain house
# Processing Record 8 of Set 13 | rio gallegos
# Processing Record 9 of Set 13 | luderitz
# Processing Record 10 of Set 13 | jalu
# Processing Record 11 of Set 13 | kang
# Processing Record 12 of Set 13 | boyuibe
# Processing Record 13 of Set 13 | luis correia
# Processing Record 14 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 13 | onguday
# Processing Record 16 of Set 13 | teodoro sampaio
# Processing Record 17 of Set 13 | mujiayingzi
# Processing Record 18 of Set 13 | biak
# Processing Record 19 of Set 13 | kashan
# Processing Record 20 of Set 13 | ampanihy
# Processing Record 21 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 22 of Set 13 | arawa
# Processing Record 23 of Set 13 | amealco
# Processing Record 24 of Set 13 | ugoofaaru
# Processing Record 25 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 26 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 13 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 28 of Set 13 | lusambo
# Processing Record 29 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 30 of Set 13 | belmonte
# Processing Record 31 of Set 13 | belaya gora
# Processing Record 32 of Set 13 | mehamn
# Processing Record 33 of Set 13 | loughrea
# Processing Record 34 of Set 13 | gimli
# Processing Record 35 of Set 13 | sur
# Processing Record 36 of Set 13 | bouake
# Processing Record 37 of Set 13 | alihe
# Processing Record 38 of Set 13 | lamu
# Processing Record 39 of Set 13 | xiuyan
# Processing Record 40 of Set 13 | salinas
# Processing Record 41 of Set 13 | tacuati
# Processing Record 42 of Set 13 | fort collins
# Processing Record 43 of Set 13 | kasumkent
# Processing Record 44 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 13 | mantua
# Processing Record 47 of Set 13 | jaltenango
# Processing Record 48 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 49 of Set 13 | rabak
# Processing Record 50 of Set 13 | nambucca heads
# Processing Record 1 of Set 14 | nicoya
# Processing Record 2 of Set 14 | ebebiyin
# Processing Record 3 of Set 14 | smithers
# Processing Record 4 of Set 14 | kathu
# Processing Record 5 of Set 14 | michalovce
# Processing Record 6 of Set 14 | antalaha
# Processing Record 7 of Set 14 | heerenveen
# Processing Record 8 of Set 14 | kralendijk
# Processing Record 9 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 14 | ambilobe
# Processing Record 11 of Set 14 | bandiagara
# Processing Record 12 of Set 14 | puerto narino
# Processing Record 13 of Set 14 | whitianga
# Processing Record 14 of Set 14 | alappuzha
# Processing Record 15 of Set 14 | mardin
# Processing Record 16 of Set 14 | kirakira
# Processing Record 17 of Set 14 | codajas
# Processing Record 18 of Set 14 | champerico
# Processing Record 19 of Set 14 | siilinjarvi
# Processing Record 20 of Set 14 | anadyr
# Processing Record 21 of Set 14 | tanout
# Processing Record 22 of Set 14 | soyo
# Processing Record 23 of Set 14 | san jeronimo
# Processing Record 24 of Set 14 | matara
# Processing Record 25 of Set 14 | ursulo galvan
# Processing Record 26 of Set 14 | longyan
# Processing Record 27 of Set 14 | sola
# Processing Record 28 of Set 14 | dryden
# Processing Record 29 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 30 of Set 14 | dekoa
# City not found. Skipping...
# Processing Record 31 of Set 14 | palmer
# Processing Record 32 of Set 14 | buta
# Processing Record 33 of Set 14 | quatre cocos
# Processing Record 34 of Set 14 | goure
# Processing Record 35 of Set 14 | gat
# Processing Record 36 of Set 14 | komsomolskiy
# Processing Record 37 of Set 14 | snyder
# Processing Record 38 of Set 14 | huilong
# Processing Record 39 of Set 14 | buala
# Processing Record 40 of Set 14 | medea
# Processing Record 41 of Set 14 | black river
# Processing Record 42 of Set 14 | porto walter
# Processing Record 43 of Set 14 | vernon
# Processing Record 44 of Set 14 | altonia
# City not found. Skipping...
# Processing Record 45 of Set 14 | novorudnyy
# Processing Record 46 of Set 14 | arlit
# Processing Record 47 of Set 14 | mpika
# Processing Record 48 of Set 14 | envira
# Processing Record 49 of Set 14 | tongchuan
# Processing Record 50 of Set 14 | beloha
# Processing Record 1 of Set 15 | cristalina
# Processing Record 2 of Set 15 | atasu
# Processing Record 3 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 4 of Set 15 | bad goisern
# Processing Record 5 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 15 | shahrud
# Processing Record 7 of Set 15 | hay river
# Processing Record 8 of Set 15 | guadalupe victoria
# Processing Record 9 of Set 15 | erenhot
# Processing Record 10 of Set 15 | puruliya
# Processing Record 11 of Set 15 | megion
# Processing Record 12 of Set 15 | coos bay
# Processing Record 13 of Set 15 | manali
# Processing Record 14 of Set 15 | nemuro
# Processing Record 15 of Set 15 | dabola
# Processing Record 16 of Set 15 | praia da vitoria
# Processing Record 17 of Set 15 | nagato
# Processing Record 18 of Set 15 | boden
# Processing Record 19 of Set 15 | namibe
# Processing Record 20 of Set 15 | luneville
# Processing Record 21 of Set 15 | port macquarie
# Processing Record 22 of Set 15 | paranaiba
# Processing Record 23 of Set 15 | yuzhnyy
# Processing Record 24 of Set 15 | urumqi
# Processing Record 25 of Set 15 | bonthe
# Processing Record 26 of Set 15 | rockhampton
# Processing Record 27 of Set 15 | barzas
# Processing Record 28 of Set 15 | sambava
# Processing Record 29 of Set 15 | ghanzi
# Processing Record 30 of Set 15 | bayangol
# Processing Record 31 of Set 15 | wegrow
# Processing Record 32 of Set 15 | broken hill
# Processing Record 33 of Set 15 | zolotinka
# City not found. Skipping...
# Processing Record 34 of Set 15 | taltal
# Processing Record 35 of Set 15 | lumeje
# Processing Record 36 of Set 15 | campos sales
# Processing Record 37 of Set 15 | bouca
# Processing Record 38 of Set 15 | villazon
# Processing Record 39 of Set 15 | myaundzha
# Processing Record 40 of Set 15 | rio grande
# Processing Record 41 of Set 15 | olafsvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Noumea -22.28  166.46     86.00        55          75        5.82
# 1  Punta Arenas -53.15  -70.92     57.20        67           0       16.11
# 2        Laguna  38.42 -121.42     63.00        38           1        5.82
# 3     Busselton -33.65  115.33     57.99        71          49        1.01
# 4         Sitka  57.05 -135.33     50.00        81          90        9.17
# 5       Kavieng  -2.57  150.80     84.61        68           0       11.34
# 6  San Patricio  28.02  -97.52     55.40        66          90        6.93
# 7         Kapaa  22.08 -159.32     82.40        65           1        8.05
# 8        Kalisz  51.76   18.09     45.00        85          95        5.99
# 9      Hermanus -34.42   19.23     64.00        83          94        5.99
#
#   Country                 Date Current Description
# 0      NC  2020-12-05 23:40:09       broken clouds
# 1      CL  2020-12-05 23:43:25           clear sky
# 2      US  2020-12-05 23:43:26           clear sky
# 3      AU  2020-12-05 23:43:26    scattered clouds
# 4      US  2020-12-05 23:43:26          light rain
# 5      PG  2020-12-05 23:43:26           clear sky
# 6      US  2020-12-05 23:43:26     overcast clouds
# 7      US  2020-12-05 23:43:26           clear sky
# 8      PL  2020-12-05 23:43:26     overcast clouds
# 9      ZA  2020-12-05 23:43:27     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", 
                    "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Noumea      NC -22.28  166.46     86.00        55          75
# 1  Punta Arenas      CL -53.15  -70.92     57.20        67           0
# 2        Laguna      US  38.42 -121.42     63.00        38           1
# 3     Busselton      AU -33.65  115.33     57.99        71          49
# 4         Sitka      US  57.05 -135.33     50.00        81          90
#
#    Wind Speed Current Description
# 0        5.82       broken clouds
# 1       16.11           clear sky
# 2        5.82           clear sky
# 3        1.01    scattered clouds
# 4        9.17          light rain

# %%
# Create the output file (CSV).
# Created a weather_database_csv folder inside the Weather_Database folder to simply take care of path error.
output_data_file = "weather_database_csv/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
